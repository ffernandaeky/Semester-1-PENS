# %% [markdown]
# ## Membuat Regresi Linear Sederhana Pada Data Pencemaran Udara Wilayah DKI Jakarta Tahun 2021

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
import pandas as pd
from sklearn import linear_model

#memanggil dataset
df=pd.read_csv('C:/Users/ekyfe/Documents/Semester 1/project stat smstr 1/statistika-dasar.csv')
df
# Out:
#     Source.Name     tanggal  pm10  so2  co  o3   no2  max critical  \
# 0         a.csv    1/1/2021    43   58  29  35  65.0   65       O3
# 1         a.csv    1/2/2021    58   86  38  64  80.0   86     PM25
# 2         a.csv    1/3/2021    64   93  25  62  86.0   93     PM25
# 3         a.csv    1/4/2021    50   67  24  31  77.0   77       O3
# 4         a.csv    1/5/2021    59   89  24  35  77.0   89     PM25
# ..          ...         ...   ...  ...  ..  ..   ...  ...      ...
# 360       l.csv  12/27/2021    75   61  23  40  47.0  121     PM25
# 361       l.csv  12/28/2021    59   53  16  34  33.0   89     PM25
# 362       l.csv  12/29/2021    61   54  15  37  29.0   98     PM25
# 363       l.csv  12/30/2021    60   53  17  38  44.0  102     PM25
# 364       l.csv  12/31/2021    64   52  44  37  53.0   90     PM25
#
#         categori location
# 0         SEDANG     DKI2
# 1         SEDANG     DKI3
# 2         SEDANG     DKI3
# 3         SEDANG     DKI2
# ...

# %%
#mengetahui jumlah dataset
print("#jumlah dataset saya : "+str(len(df.index)))
# Out:
# #jumlah dataset saya : 365

# %%
#analisis summary statistik deskriptif terhadap dataset yang dipilih 
df.describe()
# Out:
#              pm10         so2          co          o3         no2         max
# count  365.000000  365.000000  365.000000  365.000000  334.000000  365.000000
# mean    60.506849   52.753425   15.391781   49.805479   34.098802   94.030137
# std     15.155896   11.193823    5.857975   12.234790   16.623705   24.408647
# min     19.000000   37.000000    7.000000   20.000000    9.000000   45.000000
# 25%     53.000000   45.000000   11.000000   41.000000   23.000000   77.000000
# 50%     62.000000   52.000000   14.000000   49.000000   31.000000   93.000000
# 75%     68.000000   55.000000   18.000000   57.000000   39.750000  108.000000
# max    179.000000  126.000000   47.000000  151.000000  134.000000  179.000000

# %%
#menampilkan 5 row data_csv
df.head()
# Out:
#   Source.Name   tanggal  pm10  so2  co  o3   no2  max critical categori  \
# 0       a.csv  1/1/2021    43   58  29  35  65.0   65       O3   SEDANG
# 1       a.csv  1/2/2021    58   86  38  64  80.0   86     PM25   SEDANG
# 2       a.csv  1/3/2021    64   93  25  62  86.0   93     PM25   SEDANG
# 3       a.csv  1/4/2021    50   67  24  31  77.0   77       O3   SEDANG
# 4       a.csv  1/5/2021    59   89  24  35  77.0   89     PM25   SEDANG
#
#   location
# 0     DKI2
# 1     DKI3
# 2     DKI3
# 3     DKI2
# 4     DKI3

# %%
#menampilkan 15 row data_csv
df.head(15)
# Out:
#    Source.Name    tanggal  pm10  so2  co  o3   no2  max critical categori  \
# 0        a.csv   1/1/2021    43   58  29  35  65.0   65       O3   SEDANG
# 1        a.csv   1/2/2021    58   86  38  64  80.0   86     PM25   SEDANG
# 2        a.csv   1/3/2021    64   93  25  62  86.0   93     PM25   SEDANG
# 3        a.csv   1/4/2021    50   67  24  31  77.0   77       O3   SEDANG
# 4        a.csv   1/5/2021    59   89  24  35  77.0   89     PM25   SEDANG
# 5        a.csv   1/6/2021    73   81  29  66  85.0   85       O3   SEDANG
# 6        a.csv   1/7/2021    36   52  22  55  72.0   72       O3   SEDANG
# 7        a.csv   1/8/2021    38   68  26  51  71.0   71       O3   SEDANG
# 8        a.csv   1/9/2021    60   77  34  42  80.0   80       O3   SEDANG
# 9        a.csv  1/10/2021    24   39  16  38  59.0   59       O3   SEDANG
# 10       a.csv  1/11/2021    51   72  17  57  68.0   72     PM25   SEDANG
# 11       a.csv  1/12/2021    29   58  20  44  77.0   77       O3   SEDANG
# ...

# %%
# %matplotlib inline
plt.xlabel('co(karbon)')
plt.ylabel('no2(nitrogen)')
plt.scatter(df.co,df.no2, color='red')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['co']],df.co)
# Out:
# LinearRegression()

# %%
reg.predict([[20]])
# Out:
# C:\Users\ekyfe\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([20.])

# %%
reg.coef_
# Out:
# array([1.])

# %%
reg.intercept_
# Out:
# 0.0

# %%
# %matplotlib inline
plt.xlabel('co(karbon)')
plt.ylabel('no2(nitrogen)')
plt.scatter(df.co,df.no2, color='red')
plt.plot(df.co,reg.predict(df[['co']]), color='blue')
